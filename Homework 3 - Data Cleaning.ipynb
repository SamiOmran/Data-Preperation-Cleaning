# %% [markdown]
# # Sami Im

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('2015 - HW - 2.csv')

# %%
df
# Out:
#           Country                       Region  Happiness Rank  \
# 0          Greece               Western Europe           102.0
# 1            Laos            Southeastern Asia            99.0
# 2        Slovenia   Central and Eastern Europe            55.0
# 3          Zambia           Sub-Saharan Africa            85.0
# 4     Philippines            Southeastern Asia            90.0
# ..            ...                          ...             ...
# 156   Netherlands               Western Europe             7.0
# 157  Sierra Leone           Sub-Saharan Africa           123.0
# 158        Mexico  Latin America and Caribbean            14.0
# 159   South Korea                 Eastern Asia            47.0
# 160          Mali           Sub-Saharan Africa           138.0
#
#      Happiness Score  Economy (GDP per Capita)    Family  \
# 0             48.570                  11.54060   9.29330
# 1              4.876                   0.59066   0.73803
# ...

# %% [markdown]
# <h1 style='color:#c842f5'> Steps to clean: </h1>
# <br>
# <b>
#
# - Check if there is duplicate rows before doing anything and delete them.
# - Check what are the datatypes for each column and see if its right logically
# - Check for Inconsistency data and validate them.
# - Check for missing values and find thier right or approx values.
# - Detect outliers
#     </b>

# %% [markdown]
# <h1 style="color: #34eb80">1. Check duplicates and delete them</h1>

# %%
df[df.duplicated()]
# Out:
#    Country                           Region  Happiness Rank  Happiness Score  \
# 21  Jordan  Middle East and Northern Africa            82.0            5.192
# 43  Angola               Sub-Saharan Africa           137.0            4.033
# 66   Ghana               Sub-Saharan Africa           114.0            4.633
#
#     Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 21                   0.90198  1.05392                   0.69639  0.40661
# 43                   0.75778  0.86040                   0.16683  0.10384
# 66                   0.54558  0.67954                   0.40132  0.42342
#
#     Trust (Government Corruption) Generosity  Dystopia Residual
# 21                        0.14293    0.11053            1.87996
# 43                        0.07122    0.12344            1.94939
# 66                        0.04355    0.23087            2.30919

# %%
df = df.drop_duplicates()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %% [markdown]
# <h2 style="color:#3d6fad">We had 3 duplicate rows and we've deleted them </h2>
# <br>

# %% [markdown]
# <h1 style="color: #34eb80">2. Check datatypes</h1>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 0 to 160
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 152 non-null    float64
#  3   Happiness Score                152 non-null    float64
#  4   Economy (GDP per Capita)       150 non-null    float64
#  5   Family                         158 non-null    float64
#  6   Health (Life Expectancy)       142 non-null    float64
#  7   Freedom                        158 non-null    float64
#  8   Trust (Government Corruption)  158 non-null    float64
#  9   Generosity                     158 non-null    object
#  10  Dystopia Residual              158 non-null    float64
# dtypes: float64(8), object(3)
# memory usage: 14.8+ KB

# %% [markdown]
# <h2 style="color: #34b7eb">Conclusions:</h2>
# <br>
# <b>
#
# - 158 rows and 11 columns
# - 3 columns are objects rest are float
# - Country and Region should be objects(String) but Generosity should be like others factors type = float
# - Happiness Rank, Score, Econmy and Health columns have missing values
# - Rank column can be int since its just ranking(leave it end while solve the missing values)
#     </b>

# %%
df['Generosity'] = df['Generosity'].astype(float)

# %% [markdown]
# <h2 style="color: red"> We have a character ',' we need to change it to '.' </h2>
# <br>

# %%
df['Generosity'] = df['Generosity'].str.replace(',', '.')
df['Generosity'] = df['Generosity'].astype(float)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_20260\326580897.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Generosity'] = df['Generosity'].str.replace(',', '.')
# C:\Users\hp\AppData\Local\Temp\ipykernel_20260\326580897.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Generosity'] = df['Generosity'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 0 to 160
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 152 non-null    float64
#  3   Happiness Score                152 non-null    float64
#  4   Economy (GDP per Capita)       150 non-null    float64
#  5   Family                         158 non-null    float64
#  6   Health (Life Expectancy)       142 non-null    float64
#  7   Freedom                        158 non-null    float64
#  8   Trust (Government Corruption)  158 non-null    float64
#  9   Generosity                     158 non-null    float64
#  10  Dystopia Residual              158 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 14.8+ KB

# %%
df.head(3)
# Out:
#     Country                      Region  Happiness Rank  Happiness Score  \
# 0    Greece              Western Europe           102.0           48.570
# 1      Laos           Southeastern Asia            99.0            4.876
# 2  Slovenia  Central and Eastern Europe            55.0            5.848
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                  11.54060  9.29330                   8.82130  0.76990
# 1                   0.59066  0.73803                   0.54909  0.59591
# 2                   1.18498  1.27385                   0.87337  0.60855
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.13970     0.00000           18.01010
# 1                        0.24249     0.42192            1.73799
# 2                        0.03787     0.25328            1.61583

# %% [markdown]
# <h2 style="color:#3d6fad"> After converting the type to float, we checked df.info() and displayed the data to make sure we are working correctly </h2>
# <br>

# %% [markdown]
# <h1 style="color: #34eb80">3. Check for inconsistencies data</h1>
#
# <h3> Since we have 9 columns float, they only have numeric values so we need to check String columns</h3>

# %%
df['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Western Europe                     21
# Latin America and Caribbean        21
# Middle East and Northern Africa    21
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %% [markdown]
# ## We need to display all of the countries to check them
# <br>

# %%
df[df['Region'] == 'Southeastern Asia']
# Out:
#          Country             Region  Happiness Rank  Happiness Score  \
# 1           Laos  Southeastern Asia            99.0            4.876
# 4    Philippines  Southeastern Asia            90.0            5.073
# 25      Cambodia  Southeastern Asia           145.0            3.819
# 55       Myanmar  Southeastern Asia           129.0            4.307
# 92     Indonesia  Southeastern Asia            74.0            5.399
# 93      Thailand  Southeastern Asia            34.0            6.455
# 120     Malaysia  Southeastern Asia            61.0            5.770
# 130      Vietnam  Southeastern Asia            75.0            5.360
# 147    Singapore  Southeastern Asia            24.0            6.798
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 1                     0.59066  0.73803                   0.54909  0.59591
# 4                     0.70532  1.03516                   0.58114  0.62545
# ...

# %%
df[df['Region'] == 'Southern Asia']
# Out:
#          Country         Region  Happiness Rank  Happiness Score  \
# 17    Bangladesh  Southern Asia           109.0            4.694
# 35     Sri Lanka  Southern Asia           132.0            4.271
# 45         India  Southern Asia           117.0            4.565
# 48   Afghanistan  Southern Asia           153.0            3.575
# 60      Pakistan  Southern Asia            81.0            5.194
# 139        Nepal  Southern Asia           121.0            4.514
# 151       Bhutan  Southern Asia            79.0            5.253
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 17                    0.39753  0.43106                   0.60164  0.40820
# 35                    0.83524  1.01905                   0.70806  0.53726
# 45                    0.64499  0.38174                   0.51529  0.39786
# 48                    0.31982  0.30285                   0.30335  0.23414
# 60                    0.59543  0.41411                   0.51466  0.12102
# ...

# %%
df[df['Region'] == 'Eastern Asia']
# Out:
#          Country        Region  Happiness Rank  Happiness Score  \
# 52         China  Eastern Asia            84.0            5.140
# 53     Hong Kong  Eastern Asia            72.0            5.474
# 117     Mongolia  Eastern Asia           100.0            4.874
# 124       Taiwan  Eastern Asia            38.0            6.298
# 125        Japan  Eastern Asia            46.0            5.987
# 159  South Korea  Eastern Asia            47.0            5.984
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 52                    0.89012  0.94675                   0.81658  0.51697
# 53                    1.38604  1.05818                   1.01328  0.59608
# 117                   0.82819  1.30060                   0.60268  0.43626
# 124                   1.29098  1.07617                   0.87530  0.39740
# 125                   1.27074  1.25712                   0.99111  0.49615
# ...

# %%
df[df['Region'] =='North America']
# Out:
#            Country         Region  Happiness Rank  Happiness Score  \
# 69   United States  North America             NaN            7.119
# 146         Canada  North America             5.0            7.427
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 69                    1.39451  1.24711                   0.86179  0.54604
# 146                   1.32629  1.32261                   0.90563  0.63297
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 69                         0.15890     0.40105            2.51011
# 146                        0.32957     0.45811            2.45176

# %%
df[df['Region'] == 'Australia and New Zealand']
# Out:
#          Country                     Region  Happiness Rank  Happiness Score  \
# 136    Australia  Australia and New Zealand            10.0            7.284
# 149  New Zealand  Australia and New Zealand             9.0            7.286
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 136                   1.33358  1.30923                   0.93156  0.65124
# 149                   1.25018  1.31967                   0.90837  0.63938
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 136                        0.35637     0.43562            2.26646
# 149                        0.42922     0.47501            2.26425

# %%
df[df['Region'] == 'Middle East and Northern Africa']
# Out:
#                      Country                           Region  Happiness Rank  \
# 12                      Iraq  Middle East and Northern Africa           112.0
# 15                     Qatar  Middle East and Northern Africa            28.0
# 18   Palestinian Territories  Middle East and Northern Africa           108.0
# 20                    Jordan  Middle East and Northern Africa            82.0
# 27                     Egypt  Middle East and Northern Africa           135.0
# 33              Saudi Arabia  Middle East and Northern Africa            35.0
# 38                   Bahrain  Middle East and Northern Africa            49.0
# 41      United Arab Emirates  Middle East and Northern Africa            20.0
# 57                   Morocco  Middle East and Northern Africa           920.0
# 59                    Kuwait  Middle East and Northern Africa            39.0
# 76                     Yemen  Middle East and Northern Africa           136.0
# ...

# %% [markdown]
# <p style="color: purple; font-size: large"> We noticed in this region 'Middle East and Northern Africa' there is a duplicate for <b>Tunisia</b> country we didn't caught</p>
# <br>

# %%
df[df['Country'] == 'Tunisia']
# Out:
#     Country                           Region  Happiness Rank  Happiness Score  \
# 86  Tunisia  Middle East and Northern Africa           107.0            4.739
# 87  Tunisia  Middle East and Northern Africa           107.0            4.739
#
#     Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 86                       NaN  0.60429                   0.73793  0.26268
# 87                   0.88113  0.60429                   0.73793  0.26268
#
#     Trust (Government Corruption)  Generosity  Dystopia Residual
# 86                        0.06358     0.06431            2.12466
# 87                        0.06358     0.06431            2.12466

# %% [markdown]
# <p> It seems the first time it was inserted, they missed to fill the <b>Economy (GDP per Capita) column</b>, so they re-inserted it with the missing value<p/>
#
# <h3 style="color:#3d6fad" > We don't need the first record, so we have to drop it</h3>

# %%
df = df.drop(86)

# %%
df[df['Country'] == 'Tunisia']
# Out:
#     Country                           Region  Happiness Rank  Happiness Score  \
# 87  Tunisia  Middle East and Northern Africa           107.0            4.739
#
#     Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 87                   0.88113  0.60429                   0.73793  0.26268
#
#     Trust (Government Corruption)  Generosity  Dystopia Residual
# 87                        0.06358     0.06431            2.12466

# %%
df[df['Region'] == 'Latin America and Caribbean']
# Out:
#                  Country                       Region  Happiness Rank  \
# 9            El Salvador  Latin America and Caribbean            42.0
# 26                  Peru  Latin America and Caribbean            58.0
# 34              Colombia  Latin America and Caribbean            33.0
# 61             Argentina  Latin America and Caribbean            30.0
# 62               Ecuador  Latin America and Caribbean            48.0
# 67                 Chile  Latin America and Caribbean            27.0
# 82                 Haiti  Latin America and Caribbean           119.0
# 83               Uruguay  Latin America and Caribbean            32.0
# 85             Nicaragua  Latin America and Caribbean            57.0
# 100  Trinidad and Tobago  Latin America and Caribbean            41.0
# 101              Jamaica  Latin America and Caribbean            65.0
# 104           Costa Rica  Latin America and Caribbean            12.0
# ...

# %%
df[df['Region'] == 'Sub-Saharan Africa']
# Out:
#                       Country              Region  Happiness Rank  \
# 3                      Zambia  Sub-Saharan Africa            85.0
# 13                    Nigeria  Sub-Saharan Africa            78.0
# 14                      Niger  Sub-Saharan Africa           144.0
# 16                     Rwanda  Sub-Saharan Africa           154.0
# 23                 Mozambique  Sub-Saharan Africa            94.0
# 24               South Africa  Sub-Saharan Africa           113.0
# 29        Congo (Brazzaville)  Sub-Saharan Africa           139.0
# 32                 Madagascar  Sub-Saharan Africa           147.0
# 36                      Kenya  Sub-Saharan Africa           125.0
# 37                    Liberia  Sub-Saharan Africa           116.0
# 39                     Guinea  Sub-Saharan Africa           150.0
# 40                    Senegal  Sub-Saharan Africa           142.0
# 42                     Angola  Sub-Saharan Africa           137.0
# ...

# %%
df[df['Region'] == 'Western Europe']
# Out:
#             Country          Region  Happiness Rank  Happiness Score  \
# 0            Greece  Western Europe           102.0            48.57
# 6             Italy  Western Europe            50.0            59.48
# 10           France  Western Europe            29.0            65.75
# 11            Malta  Western Europe            37.0            63.02
# 19           Norway  Western Europe             4.0            75.22
# 28          Iceland  Western Europe             2.0            75.61
# 30            Spain  Western Europe             NaN            63.29
# 51          Denmark  Western Europe             3.0            75.27
# 68           Sweden  Western Europe             8.0            73.64
# 77       Luxembourg  Western Europe            17.0            69.46
# 79           Cyprus  Western Europe            67.0            56.89
# 80          Belgium  Western Europe            19.0            69.37
# 84          Ireland  Western Europe            18.0            69.40
# ...

# %%
df[df['Region'] == 'Central and Eastern Europe']
# Out:
#                     Country                      Region  Happiness Rank  \
# 2                  Slovenia  Central and Eastern Europe            55.0
# 5                   Estonia  Central and Eastern Europe            73.0
# 7              Turkmenistan  Central and Eastern Europe            70.0
# 8                   Georgia  Central and Eastern Europe           130.0
# 22               Azerbaijan  Central and Eastern Europe            80.0
# 31           Czech Republic  Central and Eastern Europe            31.0
# 44                   Latvia  Central and Eastern Europe            89.0
# 47   Bosnia and Herzegovina  Central and Eastern Europe            96.0
# 56                 Slovakia  Central and Eastern Europe            45.0
# 64                  Moldova  Central and Eastern Europe             NaN
# 72               Montenegro  Central and Eastern Europe            82.0
# 73                  Hungary  Central and Eastern Europe           104.0
# ...

# %% [markdown]
# <h2 style="color:#3d6fad">I checked all countrie's names and letter cases, and all clear</h2>

# %% [markdown]
# <h1 style="color: #34eb80">4. Check missing values</h1>

# %%
df.isna().sum()
# Out:
# Country                           0
# Region                            0
# Happiness Rank                    6
# Happiness Score                   6
# Economy (GDP per Capita)          7
# Family                            0
# Health (Life Expectancy)         16
# Freedom                           0
# Trust (Government Corruption)     0
# Generosity                        0
# Dystopia Residual                 0
# dtype: int64

# %% [markdown]
# ### For Score column, we can get the value by summing all factors columns and get the score, if all factors are present
# ###  For Rank column, if we have the score value we can sort the df and see what rank it lays between

# %% [markdown]
# <h2> First get missing values from factors column </h2>

# %%
factors = {
    'eco': 'Economy (GDP per Capita)',
    'fam': 'Family',
    'health': 'Health (Life Expectancy)',
    'free': 'Freedom',
    'trust': 'Trust (Government Corruption)',
    'gen': 'Generosity',
    'dys': 'Dystopia Residual'
}

# %%
df[(df['Health (Life Expectancy)'].isna()) & (df['Happiness Score'].notna())].head(3)
# Out:
#     Country                           Region  Happiness Rank  Happiness Score  \
# 12     Iraq  Middle East and Northern Africa           112.0            4.677
# 13  Nigeria               Sub-Saharan Africa            78.0            5.268
# 19   Norway                   Western Europe             4.0           75.220
#
#     Economy (GDP per Capita)    Family  Health (Life Expectancy)  Freedom  \
# 12                   0.98549   0.81889                       NaN  0.00000
# 13                   0.65435   0.90432                       NaN  0.34334
# 19                  14.59000  13.30950                       NaN  6.69730
#
#     Trust (Government Corruption)  Generosity  Dystopia Residual
# 12                        0.13788     0.17922            1.95335
# 13                        0.04030     0.27233            2.89319
# 19                        3.65030     3.46990           24.65310

# %%
def calculate_missing(score, factors):
    '''
        This function takes the Happiness score value and the factors as list
        and returns the missing value
    '''
    return score - sum(factors)

# %%
df['Health (Life Expectancy)'] = df['Health (Life Expectancy)'].fillna(
    calculate_missing(df['Happiness Score'], [
        df[factors.get('eco')],
        df[factors.get('fam')],
        df[factors.get('free')],
        df[factors.get('trust')],
        df[factors.get('gen')],
        df[factors.get('dys')]
    ]))

# %%
df['Economy (GDP per Capita)'] = df['Economy (GDP per Capita)'].fillna(
    calculate_missing(df['Happiness Score'], [
        df[factors.get('health')],
        df[factors.get('fam')],
        df[factors.get('free')],
        df[factors.get('trust')],
        df[factors.get('gen')],
        df[factors.get('dys')]
    ]))

# %%
df['Happiness Score'] = df['Happiness Score'].fillna(sum([
    df[factors.get('eco')],    
    df[factors.get('fam')],
    df[factors.get('health')],
    df[factors.get('free')],
    df[factors.get('trust')],
    df[factors.get('gen')],
    df[factors.get('dys')]
    ])
)

# %%
df.isna().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   6
# Happiness Score                  6
# Economy (GDP per Capita)         4
# Family                           0
# Health (Life Expectancy)         5
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# <h2 style="color:#3d6fad"> Here we see that we decreased the number of missing values from Health & Econmy columns </h2>

# %% [markdown]
# <h1 style="color:red"> Notes: </h1>
#
# <ul style="color: #3d6fad; font-weight: bold">
#     <li>We have missing values in Happiness Rank and Happiness Score columns </li>
#     <li>Happiness Rank is based on the Score column, so if we found the missing values in Happiness Score we can give each country its correct Rank. </li>
#     <li> We can impute the missing Scores by setting the Region's mean, since all countries in the region have close scores value </li>
#  </ul>

# %%
df[(df['Happiness Rank'].isna()) | (df['Happiness Score'].isna())]
# Out:
#             Country                       Region  Happiness Rank  \
# 9       El Salvador  Latin America and Caribbean            42.0
# 26             Peru  Latin America and Caribbean            58.0
# 30            Spain               Western Europe             NaN
# 64          Moldova   Central and Eastern Europe             NaN
# 69    United States                North America             NaN
# 81          Croatia   Central and Eastern Europe             NaN
# 88          Romania   Central and Eastern Europe             NaN
# 91         Ethiopia           Sub-Saharan Africa           122.0
# 104      Costa Rica  Latin America and Caribbean            12.0
# 121  United Kingdom               Western Europe            21.0
# 138      Kyrgyzstan   Central and Eastern Europe            77.0
# 154         Bolivia  Latin America and Caribbean             NaN
#
#      Happiness Score  Economy (GDP per Capita)    Family  \
# 9                NaN                   0.76454   1.02507
# ...

# %%
df.groupby('Region')['Happiness Score'].mean().to_dict()
# Out:
# {'Australia and New Zealand': 7.285,
#  'Central and Eastern Europe': 5.334607142857143,
#  'Eastern Asia': 5.626166666666666,
#  'Latin America and Caribbean': 6.173222222222222,
#  'Middle East and Northern Africa': 5.4069,
#  'North America': 7.273,
#  'Southeastern Asia': 5.317444444444444,
#  'Southern Asia': 4.580857142857143,
#  'Sub-Saharan Africa': 4.194871794871795,
#  'Western Europe': 66.8075}

# %% [markdown]
# <h2> Above we can see the average for each region happiness score, we will need it to check if we filled the data correctly </h2>

# %%
regions = df['Region'].unique()
regions
# Out:
# array(['Western Europe', 'Southeastern Asia',
#        'Central and Eastern Europe', 'Sub-Saharan Africa',
#        'Latin America and Caribbean', 'Middle East and Northern Africa',
#        'Southern Asia', 'Eastern Asia', 'North America',
#        'Australia and New Zealand'], dtype=object)

# %%
df['Happiness Score'] = df.groupby('Region')['Happiness Score'].transform(lambda x: x.fillna(x.mean()))

# %%
df
# Out:
#           Country                       Region  Happiness Rank  \
# 0          Greece               Western Europe           102.0
# 1            Laos            Southeastern Asia            99.0
# 2        Slovenia   Central and Eastern Europe            55.0
# 3          Zambia           Sub-Saharan Africa            85.0
# 4     Philippines            Southeastern Asia            90.0
# ..            ...                          ...             ...
# 156   Netherlands               Western Europe             7.0
# 157  Sierra Leone           Sub-Saharan Africa           123.0
# 158        Mexico  Latin America and Caribbean            14.0
# 159   South Korea                 Eastern Asia            47.0
# 160          Mali           Sub-Saharan Africa           138.0
#
#      Happiness Score  Economy (GDP per Capita)    Family  \
# 0             48.570                  11.54060   9.29330
# 1              4.876                   0.59066   0.73803
# ...

# %%
df[df['Happiness Score'].isna()]
# Out:
# Empty DataFrame
# Columns: [Country, Region, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual]
# Index: []

# %%
df.loc[9]
# Out:
# Country                                          El Salvador
# Region                           Latin America and Caribbean
# Happiness Rank                                          42.0
# Happiness Score                                     6.173222
# Economy (GDP per Capita)                             0.76454
# Family                                               1.02507
# Health (Life Expectancy)                                 NaN
# Freedom                                               0.4035
# Trust (Government Corruption)                        0.11776
# Generosity                                           0.10692
# Dystopia Residual                                      3.035
# Name: 9, dtype: object

# %% [markdown]
# <H2 style="color:#3d6fad"> Here we can see we no longer have missing values in Happiness Score column and we checked one of the rows and its correct. </H2>
#
# <h2> Now we can calculate the missing values in Econmy and health, we can just rerun the previous above cells that made this functionality </h2>

# %%
df.isna().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   6
# Happiness Score                  0
# Economy (GDP per Capita)         4
# Family                           0
# Health (Life Expectancy)         5
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df[df['Health (Life Expectancy)'].isna()]
# Out:
#             Country                       Region  Happiness Rank  \
# 9       El Salvador  Latin America and Caribbean            42.0
# 26             Peru  Latin America and Caribbean            58.0
# 91         Ethiopia           Sub-Saharan Africa           122.0
# 121  United Kingdom               Western Europe            21.0
# 138      Kyrgyzstan   Central and Eastern Europe            77.0
#
#      Happiness Score  Economy (GDP per Capita)    Family  \
# 9           6.173222                   0.76454   1.02507
# 26          6.173222                       NaN   0.97459
# 91          4.194872                       NaN   0.60406
# 121        66.807500                  12.66370  12.85480
# 138         5.334607                       NaN   1.15115
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 9                         NaN  0.40350                        0.11776
# 26                        NaN  0.41496                        0.05989
# ...

# %% [markdown]
# <h2> We only fixed 3 rows, and the others can't impute the missing values since we have two missing values on the same row </h2>
# <br>

# %%
df[(df['Happiness Rank'].isnull())]
# Out:
#            Country                       Region  Happiness Rank  \
# 30           Spain               Western Europe             NaN
# 64         Moldova   Central and Eastern Europe             NaN
# 69   United States                North America             NaN
# 81         Croatia   Central and Eastern Europe             NaN
# 88         Romania   Central and Eastern Europe             NaN
# 154        Bolivia  Latin America and Caribbean             NaN
#
#      Happiness Score  Economy (GDP per Capita)    Family  \
# 30            63.290                  12.30110  13.13790
# 64             5.889                   0.59448   1.01528
# 69             7.119                   1.39451   1.24711
# 81             5.759                   1.08254   0.79624
# 88             5.124                   1.04345   0.88588
# 154            5.890                   0.68133   0.97841
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %% [markdown]
# <h2> Now we need to fix the rank, but first we will sort df based on score </h2>

# %%
df = df.sort_values(by='Happiness Score', ascending=False).reset_index(drop=True)
df.head(20)
# Out:
#            Country          Region  Happiness Rank  Happiness Score  \
# 0      Switzerland  Western Europe             1.0          75.8700
# 1          Iceland  Western Europe             2.0          75.6100
# 2          Denmark  Western Europe             3.0          75.2700
# 3           Norway  Western Europe             4.0          75.2200
# 4          Finland  Western Europe             6.0          74.0600
# 5      Netherlands  Western Europe             7.0          73.7800
# 6           Sweden  Western Europe             8.0          73.6400
# 7          Austria  Western Europe            13.0          72.0000
# 8       Luxembourg  Western Europe            17.0          69.4600
# 9          Ireland  Western Europe            18.0          69.4000
# 10         Belgium  Western Europe            19.0          69.3700
# 11         Germany  Western Europe            26.0          67.5000
# 12  United Kingdom  Western Europe            21.0          66.8075
# ...

# %%
df.tail(20)
# Out:
#                       Country                           Region  \
# 137       Congo (Brazzaville)               Sub-Saharan Africa
# 138                   Comoros               Sub-Saharan Africa
# 139                    Uganda               Sub-Saharan Africa
# 140                   Senegal               Sub-Saharan Africa
# 141                     Gabon               Sub-Saharan Africa
# 142                     Niger               Sub-Saharan Africa
# 143                  Cambodia                Southeastern Asia
# 144                  Tanzania               Sub-Saharan Africa
# 145                Madagascar               Sub-Saharan Africa
# 146  Central African Republic               Sub-Saharan Africa
# 147                      Chad               Sub-Saharan Africa
# 148                    Guinea               Sub-Saharan Africa
# 149               Ivory Coast               Sub-Saharan Africa
# 150              Burkina Faso               Sub-Saharan Africa
# ...

# %%
df['Happiness Rank'] = df.index + 1

# %%
df.head(20)
# Out:
#            Country          Region  Happiness Rank  Happiness Score  \
# 0      Switzerland  Western Europe               1          75.8700
# 1          Iceland  Western Europe               2          75.6100
# 2          Denmark  Western Europe               3          75.2700
# 3           Norway  Western Europe               4          75.2200
# 4          Finland  Western Europe               5          74.0600
# 5      Netherlands  Western Europe               6          73.7800
# 6           Sweden  Western Europe               7          73.6400
# 7          Austria  Western Europe               8          72.0000
# 8       Luxembourg  Western Europe               9          69.4600
# 9          Ireland  Western Europe              10          69.4000
# 10         Belgium  Western Europe              11          69.3700
# 11         Germany  Western Europe              12          67.5000
# 12  United Kingdom  Western Europe              13          66.8075
# ...

# %% [markdown]
# # As we can see, we fixed the ranks values.
# <br>

# %% [markdown]
# <h1 style="color: #34eb80">5. Detect outliers</h1>

# %%
# mean = df['Happiness Score'].mean()
# std = df['Happiness Score'].std()

# df['Z Score'] = (df['Happiness Score'] - mean) / std

# %%
# df

# %%
# outliers = df[(df['Happiness Score'] > 3 * std) | (df['Happiness Score'] < -3 * std)]

# %%
# outliers

# %%
df['Happiness Score'].describe()
# Out:
# count    157.000000
# mean      13.414189
# std       21.276105
# min        2.839000
# 25%        4.518000
# 50%        5.332000
# 75%        6.455000
# max       75.870000
# Name: Happiness Score, dtype: float64

# %%
Q1 = 4.518000
Q3 = 6.455000
IQR = Q3 - Q1

# %%
above = Q3 + 1.5 * IQR
below = Q1 - 1.5 * IQR

# %%
outliers_2 = df[(df['Happiness Score'] > above) | (df['Happiness Score'] < below)]

# %%
outliers_2
# Out:
#            Country          Region  Happiness Rank  Happiness Score  \
# 0      Switzerland  Western Europe               1          75.8700
# 1          Iceland  Western Europe               2          75.6100
# 2          Denmark  Western Europe               3          75.2700
# 3           Norway  Western Europe               4          75.2200
# 4          Finland  Western Europe               5          74.0600
# 5      Netherlands  Western Europe               6          73.7800
# 6           Sweden  Western Europe               7          73.6400
# 7          Austria  Western Europe               8          72.0000
# 8       Luxembourg  Western Europe               9          69.4600
# 9          Ireland  Western Europe              10          69.4000
# 10         Belgium  Western Europe              11          69.3700
# 11         Germany  Western Europe              12          67.5000
# 12  United Kingdom  Western Europe              13          66.8075
# ...

# %% [markdown]
# <h1> I used the quantile method to detect outliers and we can notice all of them are from western europe </h1>
#
# <h1 style='color: #5cd66e'> The dataframe is ready to use
# </h1>
